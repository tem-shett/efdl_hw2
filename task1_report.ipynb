# %%
# !torchrun --nproc_per_node 10 sequential_print.py
# Out:
# W0216 00:19:59.622000 387997 torch/distributed/run.py:793]
# W0216 00:19:59.622000 387997 torch/distributed/run.py:793] *****************************************
# W0216 00:19:59.622000 387997 torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0216 00:19:59.622000 387997 torch/distributed/run.py:793] *****************************************
# Process 0
# Process 1
# Process 2
# Process 3
# Process 4
# Process 5
# Process 6
# Process 7
# Process 8
# Process 9
# Process 9
# Process 8
# Process 7
# Process 6
# Process 5
# Process 4
# Process 3
# Process 2
# Process 1
# Process 0
# ---
# Process 0
# Process 1
# Process 2
# Process 3
# Process 4
# Process 5
# Process 6
# Process 7
# Process 8
# Process 9
# Process 9
# Process 8
# Process 7
# Process 6
# Process 5
# Process 4
# Process 3
# Process 2
# ...
