# %%
# !python3 allreduce.py
# Out:
# Rank  0  has data  tensor([-1.1258, -1.1524, -0.2506, -0.4339,  0.8487,  0.6920, -0.3160, -2.1152,
#          0.3223, -1.2633,  1.4437,  0.2660,  0.1665,  0.8744, -0.1435, -0.1116,
#         -0.6136,  0.0316,  2.0050,  0.0537,  0.6181, -0.4128, -0.8411, -2.3160,
#         -0.1023,  0.7924])
# Rank  1  has data  tensor([-1.5256, -0.7502, -0.6540, -1.6095, -0.1002, -0.6092, -0.9798, -1.6091,
#         -0.7121,  0.3037,  1.7674, -0.0954,  0.1394, -1.5785, -0.3206, -0.2993,
#          1.8793, -0.0721,  0.2753,  1.7163, -0.0561,  0.9107, -1.3924,  2.6891,
#         -0.1110,  0.2927])
# Rank  2  has data  tensor([-1.0408,  0.9166, -1.3042, -1.1097, -1.2188,  1.1676, -1.0574, -0.1188,
#         -0.9078,  0.3452, -1.1233, -0.0919, -0.1320, -0.2751, -0.2350,  0.0937,
#         -0.7650,  1.8299, -0.1752,  0.6990, -0.6861,  0.7202,  0.1963,  0.6142,
#          1.1566,  0.4296])
# Rank  3  has data  tensor([-0.0766,  0.3599, -0.7820,  0.0715,  0.6648, -0.2868,  1.6206, -1.5967,
# ...

# %% [markdown]
# Работает правильно!

# %%
from benchmark_allreduce import run_benchmarks

run_benchmarks()
# Out:
# 2 workers
# 4 workers
# 8 workers
# 16 workers
#          type  workers    size    time(ms)   mem(KB)
# 0   butterfly        2    1000    0.677007  3.578125
# 1     my ring        2    1000    0.326146  1.484375
# 2       torch        2    1000    0.199436  1.757812
# 3   butterfly        2   10000    0.263806  0.812500
# 4     my ring        2   10000    0.223920  0.585938
# 5       torch        2   10000    0.207947  0.500000
# 6   butterfly        2  100000   14.928744  0.812500
# 7     my ring        2  100000   13.994336  0.585938
# 8       torch        2  100000    7.113319  0.500000
# 9   butterfly        4    1000    0.811972  4.179688
# 10    my ring        4    1000    0.702351  1.734375
# 11      torch        4    1000    0.498888  1.757812
# 12  butterfly        4   10000    0.521868  1.414062
# 13    my ring        4   10000    0.564223  0.835938
# 14      torch        4   10000    0.471978  0.500000
# 15  butterfly        4  100000   27.586755  1.414062
# ...
