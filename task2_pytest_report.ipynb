# %%
# !pytest test_syncbn.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.12, pytest-8.2.0, pluggy-1.5.0
# rootdir: /home/tem_shett/porn/hsehw/efdl/hw2
# plugins: dash-2.18.1, hydra-core-1.3.2, cov-5.0.0, anyio-4.1.0, langsmith-0.3.31
# collected 16 items
#
# test_syncbn.py ................                                          [100%]
#
# ============================= 16 passed in 35.40s ==============================
